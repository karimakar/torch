# %% [markdown]
# #                    DECISION TREE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
df1=sns.load_dataset('iris')
df1.tail(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df1.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# ### loading the Dataset

# %%
df = sns.load_dataset('iris')

# %%
df.head(15)   # first five record
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  species
# 0            5.1          3.5           1.4          0.2        0
# 1            4.9          3.0           1.4          0.2        0
# 2            4.7          3.2           1.3          0.2        0
# 3            4.6          3.1           1.5          0.2        0
# 4            5.0          3.6           1.4          0.2        0
# 5            5.4          3.9           1.7          0.4        0
# 6            4.6          3.4           1.4          0.3        0
# 7            5.0          3.4           1.5          0.2        0
# 8            4.4          2.9           1.4          0.2        0
# 9            4.9          3.1           1.5          0.1        0
# 10           5.4          3.7           1.5          0.2        0
# 11           4.8          3.4           1.6          0.2        0
# 12           4.8          3.0           1.4          0.1        0
# ...

# %% [markdown]
# ## Maping sepices feature values setosa,versicolor,virginica

# %%
df['species'] = df['species'].map({'setosa':0,'versicolor':1,'virginica':2})

# %% [markdown]
# ### importing DECISION TREE CLASSIFIER FROM SKLEARN LIBRARY

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### Initializing DecsionTreeClassifier module first paramter is criterion = "entropy"

# %% [markdown]
# #### post Prunning ''

# %%
classifier = DecisionTreeClassifier(criterion="entropy")

# %% [markdown]
# #### Fitting the data(FIRST:Independant features,secand param :y dependent feature)

# %%
classifier.fit(df.iloc[:,:-1],df.iloc[:,-1])
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
from sklearn import tree

# %% [markdown]
# #### by default the overfitting decision tree max = none

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(classifier,filled=True)
# Out:
# [Text(0.5, 0.9166666666666666, 'X[3] <= 0.8\nentropy = 1.585\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.5769230769230769, 0.75, 'X[3] <= 1.75\nentropy = 1.0\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.3076923076923077, 0.5833333333333334, 'X[2] <= 4.95\nentropy = 0.445\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'X[3] <= 1.65\nentropy = 0.146\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'entropy = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'X[3] <= 1.55\nentropy = 0.918\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'X[0] <= 6.95\nentropy = 0.918\nsamples = 3\nvalue = [0, 2, 1]'),
# ...

# %%
classifier = DecisionTreeClassifier(criterion="entropy",max_depth=2)
classifier.fit(df.iloc[:,:-1],df.iloc[:,-1])
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=2)

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(classifier,filled=True)
# Out:
# [Text(0.4, 0.8333333333333334, 'X[2] <= 2.45\nentropy = 1.585\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.2, 0.5, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.6, 0.5, 'X[3] <= 1.75\nentropy = 1.0\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.4, 0.16666666666666666, 'entropy = 0.445\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.8, 0.16666666666666666, 'entropy = 0.151\nsamples = 46\nvalue = [0, 1, 45]')]

# %% [markdown]
# ## Here is not using Max_dept & criterion  is Gini

# %%
classifier = DecisionTreeClassifier(criterion='gini')
classifier.fit(df.iloc[:,:-1],df.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(classifier,filled=True)
# Out:
# [Text(0.5, 0.9166666666666666, 'X[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.5769230769230769, 0.75, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.3076923076923077, 0.5833333333333334, 'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'X[2] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
# ...

# %% [markdown]
# ### observation in gini the values range between 0 to 0.5

# %% [markdown]
# ### here using Max depth in 2 & cretirion gini

# %%
classifier1 = DecisionTreeClassifier(max_depth=2,criterion='gini')
classifier1.fit(df.iloc[:,:-1],df.iloc[:,-1])
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(classifier1,filled=True)
# Out:
# [Text(0.4, 0.8333333333333334, 'X[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.6, 0.5, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.043\nsamples = 46\nvalue = [0, 1, 45]')]

# %% [markdown]
# ### Pre Prunning(Forward Prunning)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.iloc[:,:-1],df.iloc[:,-1],test_size=0.30,random_state=0)

# %%
X_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 60            5.0          2.0           3.5          1.0
# 116           6.5          3.0           5.5          1.8
# 144           6.7          3.3           5.7          2.5
# 119           6.0          2.2           5.0          1.5
# 108           6.7          2.5           5.8          1.8
# ..            ...          ...           ...          ...
# 9             4.9          3.1           1.5          0.1
# 103           6.3          2.9           5.6          1.8
# 67            5.8          2.7           4.1          1.0
# 117           7.7          3.8           6.7          2.2
# 47            4.6          3.2           1.4          0.2
#
# [105 rows x 4 columns]

# %%
from sklearn.metrics import accuracy_score,classification_report

parameters = {
    'criterion':['gini','entropy'],
    'splitter':['best','random'],
    'max_depth':[1,2,3,4,5],
    'max_features':['auto','sqrt','log2']    
}

# %%
classifier1 = DecisionTreeClassifier()
gscv= GridSearchCV(classifier1,parameters,scoring='accuracy',cv=5)
gscv.fit(df.iloc[:,:-1],df.iloc[:,-1])
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [1, 2, 3, 4, 5],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %%
gscv.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 5,
#  'max_features': 'auto',
#  'splitter': 'best'}

# %%
y_train_predicted = gscv.predict(X_train)
y_test_predicted = gscv.predict(X_test)

# %% [markdown]
# ### acurracy of Training Dataset

# %%
train_score = accuracy_score(y_train,y_train_predicted)
train_score
# Out:
# 0.9904761904761905

# %% [markdown]
# ### accuracy of Test Dataset

# %%
test_score = accuracy_score(y_test,y_test_predicted)
test_score
# Out:
# 0.9777777777777777

# %%
print(classification_report(y_test_predicted,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       0.94      1.00      0.97        17
#            2       1.00      0.92      0.96        12
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.97      0.98        45
# weighted avg       0.98      0.98      0.98        45
